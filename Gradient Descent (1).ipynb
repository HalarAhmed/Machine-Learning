# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red')

# %% [markdown]
# **Applying Gradient Descent keeping slope constant i-e 78.35. Assume b=0 initially**

# %%
y_pred=((78.35*x)+0)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b=0')
plt.legend()
plt.show()

# %%
m=78.35
b=0

loss_slope=-2*np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# np.float64(-209.27763408209216)

# %%
# calculating stepsize:
lr=0.1
step_size=lr*loss_slope
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
b=b-step_size
b
# Out:
# np.float64(20.927763408209216)

# %%
y_pred1=((78.35*x)+b).reshape(4)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,y_pred1,color='#00a65a',label='b={}'.format(b))
plt.plot(x,y_pred,color='#A3E4D7',label='b=0')
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# np.float64(-41.85552681641843)

# %%
step_size=loss_slope*lr
step_size
# Out:
# np.float64(-4.185552681641844)

# %%
b=b-step_size
b
# Out:
# np.float64(25.11331608985106)

# %%
y_pred2=((78.35*x)+b).reshape(4)

# %%
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b=0')
plt.plot(x,y_pred1,color='#A3E4D7',label='b={}'.format(b))
plt.plot(x,y_pred2,color='#0f172a',label='b={}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# np.float64(-8.371105363283675)

# %%
step_size=loss_slope*lr
step_size
# Out:
# np.float64(-0.8371105363283675)

# %%
b=b-step_size
b
# Out:
# np.float64(25.95042662617943)

# %%
y_pred3=((78.35*x)+b).reshape(4)

plt.scatter(x,y)
plt.plot(x,reg.predict(x),color='red',label='OLS')
plt.plot(x,y_pred,color='#00a65a',label='b=0')
plt.plot(x,y_pred1,color='#A3E4D7',label='b={}'.format(b))
plt.plot(x,y_pred2,color='#0f172a',label='b={}'.format(b))
plt.plot(x,y_pred3,color='#220f2a',label='b={}'.format(b))
plt.legend()
